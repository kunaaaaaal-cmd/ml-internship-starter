# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/kunaaaaaal-cmd/ml-internship-starter/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# My lane is **Predicting Housing Prices** in California. This is an important area because accurate predictions can help real estate investors make informed decisions, assist homebuyers in understanding market values, and enable urban planners to assess economic trends. This work aims to provide a data-driven approach to estimate property values, offering a tangible benefit to various stakeholders in the housing market.

# %%
# This cell is for CODE (numbers, a query, a check) related to the lane description. For this section,
# the description is primarily textual, so no code is strictly necessary here.
# However, one might include code here to define specific datasets or initial parameters if applicable.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# The work improves the decision of **setting a competitive offer price for a house** (for buyers) or **determining an optimal listing price** (for sellers). A real estate agent or individual buyer/seller acts on this decision. A wrong recommendation could cost a buyer **overpaying significantly** for a property, leading to financial strain or reduced return on investment. For a seller, it could mean **underpricing** their property, resulting in lost profits, or **overpricing**, leading to a prolonged sale period and increased holding costs.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
# For this section, the answer is descriptive, so no specific code is generated.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# I will load the California Housing dataset to get an initial understanding of its structure and key characteristics. I'll focus on displaying the number of samples and features, along with the average housing price, to quickly gauge the scope and central tendency of the data. This will help confirm that the dataset is suitable for the stated lane and provides a sufficient basis for further analysis.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

from sklearn.datasets import fetch_california_housing
import pandas as pd

# Load the California Housing dataset
housing = fetch_california_housing(as_frame=True)
df = housing.frame
df['target'] = housing.target

print(f"Number of samples: {df.shape[0]}")
print(f"Number of features: {df.shape[1] - 1} (excluding target)")
print(f"Average housing price (in 100,000s USD): {df['target'].mean():.2f}")

# Display the first few rows to quickly inspect the data
# display(df.head())
# Out:
# Number of samples: 20640
# Number of features: 9 (excluding target)
# Average housing price (in 100,000s USD): 2.07

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# My work will be able to provide **observed and directional insights** into the factors influencing housing prices in California, offering **decision-support** for pricing strategies. It can suggest which features are strongly correlated with property values and how they might generally impact prices. However, it will **not be able to claim causal proof** (e.g., increasing income *causes* a direct increase in house price), nor will it predict precise future market shifts or external economic events. The model's recommendations are based on historical data and observed patterns, not a crystal ball for 'predicting Google' or other complex, non-linear market behaviors.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
# For this section, the explanation is textual, so no specific code is generated.
# One might add code here for model evaluation metrics once a model is built to support claims.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
